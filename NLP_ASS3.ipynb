# %% [markdown]
# # **TASK #1**

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab') # Added to resolve LookupError
sentence = "Students are learning Natural Language Processing"
tokens = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [('Students', 'NNS'), ('are', 'VBP'), ('learning', 'VBG'), ('Natural', 'NNP'), ('Language', 'NNP'), ('Processing', 'NNP')]

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Students are learning Natural Language Processing")
for token in doc:
    print(token.text, token.pos_)
# Out:
# Students NOUN
# are AUX
# learning VERB
# Natural PROPN
# Language PROPN
# Processing NOUN

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying a startup in India.")
for token in doc:
    print(token.text, token.pos_, token.tag_)
# Out:
# Apple PROPN NNP
# is AUX VBZ
# looking VERB VBG
# at ADP IN
# buying VERB VBG
# a DET DT
# startup NOUN NN
# in ADP IN
# India PROPN NNP
# . PUNCT .

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
text = "Loving the new AI features 😍 #AI #MachineLearning"
doc = nlp(text)
nouns = []
verbs = []
for token in doc:
    if token.pos_ in ["NOUN", "PROPN"]:
        nouns.append(token.text)
    elif token.pos_ == "VERB":
        verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'AI': 2, '😍': 1, 'MachineLearning': 1})
# Verb Frequency: Counter({'Loving': 1, 'features': 1})

# %% [markdown]
# # **TASK #2**

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab') # Added to resolve LookupError
SRUniversity="""The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities."""
tokens = nltk.word_tokenize(SRUniversity)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('The', 'DT'), ('SR', 'NNP'), ('University', 'NNP'), ('campus', 'NN'), ('is', 'VBZ'), ('located', 'VBN'), ('in', 'IN'), ('Ananthasagar', 'NNP'), ('village', 'NN'), ('of', 'IN'), ('Hasanparthy', 'NNP'), ('Mandal', 'NNP'), ('in', 'IN'), ('Warangal', 'NNP'), (',', ','), ('Telangana', 'NNP'), (',', ','), ('India', 'NNP'), ('.', '.'), ('It', 'PRP'), ('is', 'VBZ'), ('in', 'IN'), ('150', 'CD'), ('acres', 'NNS'), (',', ','), ('with', 'IN'), ('both', 'DT'), ('separate', 'JJ'), ('hostel', 'NN'), ('facilities', 'NNS'), ('for', 'IN'), ('boys', 'NNS'), ('and', 'CC'), ('girls', 'NNS'), ('.', '.'), ('There', 'EX'), ('is', 'VBZ'), ('a', 'DT'), ('huge', 'JJ'), ('central', 'JJ'), ('library', 'NN'), ('along', 'IN'), ('with', 'IN'), ('Indias', 'NNP'), ('largest', 'JJS'), ('Technology', 'NN'), ('Business', 'NNP'), ('Incubator', 'NNP'), ('(', '('), ('TBI', 'NNP'), (')', ')'), ('in', 'IN'), ('tier', '$'), ('2', 'CD'), ('cities', 'NNS'), ('.', '.')]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("""The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities""")
for token in doc:
    print(token.text, token.pos_)
# Out:
# The DET
# SR PROPN
# University PROPN
# campus NOUN
# is AUX
# located VERB
# in ADP
# Ananthasagar PROPN
# village NOUN
# of ADP
# Hasanparthy PROPN
# Mandal PROPN
# in ADP
# Warangal PROPN
# , PUNCT
# Telangana PROPN
# , PUNCT
# India PROPN
# . PUNCT
#
#  SPACE
# It PRON
# is AUX
# in ADP
# 150 NUM
# acres NOUN
# , PUNCT
# with ADP
# both DET
# separate ADJ
# hostel NOUN
# facilities NOUN
# for ADP
# boys NOUN
# and CCONJ
# girls NOUN
# . PUNCT
#
#  SPACE
# There PRON
# is VERB
# a DET
# huge ADJ
# central ADJ
# library NOUN
# along ADP
# with ADP
# Indias PROPN
# largest ADJ
# Technology PROPN
# Business PROPN
# Incubator PROPN
# ( PUNCT
# TBI PROPN
# ) PUNCT
# in ADP
# tier NOUN
# 2 NUM
# cities NOUN

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("""The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities""")
for token in doc:
    print(token.text, token.pos_, token.tag_)
# Out:
# The DET DT
# SR PROPN NNP
# University PROPN NNP
# campus NOUN NN
# is AUX VBZ
# located VERB VBN
# in ADP IN
# Ananthasagar PROPN NNP
# village NOUN NN
# of ADP IN
# Hasanparthy PROPN NNP
# Mandal PROPN NNP
# in ADP IN
# Warangal PROPN NNP
# , PUNCT ,
# Telangana PROPN NNP
# , PUNCT ,
# India PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# It PRON PRP
# is AUX VBZ
# in ADP IN
# 150 NUM CD
# acres NOUN NNS
# , PUNCT ,
# with ADP IN
# both DET DT
# separate ADJ JJ
# hostel NOUN NN
# facilities NOUN NNS
# for ADP IN
# boys NOUN NNS
# and CCONJ CC
# girls NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# There PRON EX
# is VERB VBZ
# a DET DT
# huge ADJ JJ
# central ADJ JJ
# library NOUN NN
# along ADP IN
# with ADP IN
# Indias PROPN NNP
# largest ADJ JJS
# Technology PROPN NNP
# Business PROPN NNP
# Incubator PROPN NNP
# ( PUNCT -LRB-
# TBI PROPN NNP
# ) PUNCT -RRB-
# in ADP IN
# tier NOUN NN
# 2 NUM CD
# cities NOUN NNS

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
text = """The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities"""
doc = nlp(text)
nouns = []
verbs = []
for token in doc:
    if token.pos_ in ["NOUN", "PROPN"]:
        nouns.append(token.text)
    elif token.pos_ == "VERB":
        verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'SR': 1, 'University': 1, 'campus': 1, 'Ananthasagar': 1, 'village': 1, 'Hasanparthy': 1, 'Mandal': 1, 'Warangal': 1, 'Telangana': 1, 'India': 1, 'acres': 1, 'hostel': 1, 'facilities': 1, 'boys': 1, 'girls': 1, 'library': 1, 'Indias': 1, 'Technology': 1, 'Business': 1, 'Incubator': 1, 'TBI': 1, 'tier': 1, 'cities': 1})
# Verb Frequency: Counter({'located': 1, 'is': 1})

# %% [markdown]
# # *TASK #3*

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab') # Added to resolve LookupError
sentence = """The curious student quickly opened his notebook and wrote a short story about a brave fox.
While the fox ran through the forest, it jumped over fallen trees and chased playful rabbits.
Suddenly, a loud noise frightened the animals, but the fox continued running with great determination.
"""
tokens = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('The', 'DT'), ('curious', 'JJ'), ('student', 'NN'), ('quickly', 'RB'), ('opened', 'VBD'), ('his', 'PRP$'), ('notebook', 'NN'), ('and', 'CC'), ('wrote', 'VBD'), ('a', 'DT'), ('short', 'JJ'), ('story', 'NN'), ('about', 'IN'), ('a', 'DT'), ('brave', 'NN'), ('fox', 'NN'), ('.', '.'), ('While', 'IN'), ('the', 'DT'), ('fox', 'NN'), ('ran', 'VBD'), ('through', 'IN'), ('the', 'DT'), ('forest', 'JJS'), (',', ','), ('it', 'PRP'), ('jumped', 'VBD'), ('over', 'IN'), ('fallen', 'VBN'), ('trees', 'NNS'), ('and', 'CC'), ('chased', 'VBN'), ('playful', 'JJ'), ('rabbits', 'NNS'), ('.', '.'), ('Suddenly', 'RB'), (',', ','), ('a', 'DT'), ('loud', 'JJ'), ('noise', 'NN'), ('frightened', 'VBD'), ('the', 'DT'), ('animals', 'NNS'), (',', ','), ('but', 'CC'), ('the', 'DT'), ('fox', 'JJ'), ('continued', 'VBD'), ('running', 'VBG'), ('with', 'IN'), ('great', 'JJ'), ('determination', 'NN'), ('.', '.')]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("""The curious student quickly opened his notebook and wrote a short story about a brave fox.
While the fox ran through the forest, it jumped over fallen trees and chased playful rabbits.
Suddenly, a loud noise frightened the animals, but the fox continued running with great determination.""")
for token in doc:
    print(token.text, token.pos_)
# Out:
# The DET
# curious ADJ
# student NOUN
# quickly ADV
# opened VERB
# his PRON
# notebook NOUN
# and CCONJ
# wrote VERB
# a DET
# short ADJ
# story NOUN
# about ADP
# a DET
# brave ADJ
# fox NOUN
# . PUNCT
#
#  SPACE
# While SCONJ
# the DET
# fox NOUN
# ran VERB
# through ADP
# the DET
# forest NOUN
# , PUNCT
# it PRON
# jumped VERB
# over ADP
# fallen VERB
# trees NOUN
# and CCONJ
# chased VERB
# playful ADJ
# rabbits NOUN
# . PUNCT
#
#  SPACE
# Suddenly ADV
# , PUNCT
# a DET
# loud ADJ
# noise NOUN
# frightened VERB
# the DET
# animals NOUN
# , PUNCT
# but CCONJ
# the DET
# fox NOUN
# continued VERB
# running VERB
# with ADP
# great ADJ
# determination NOUN
# . PUNCT

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("""The curious student quickly opened his notebook and wrote a short story about a brave fox.
While the fox ran through the forest, it jumped over fallen trees and chased playful rabbits.
Suddenly, a loud noise frightened the animals, but the fox continued running with great determination""")
for token in doc:
    print(token.text, token.pos_, token.tag_)
# Out:
# The DET DT
# curious ADJ JJ
# student NOUN NN
# quickly ADV RB
# opened VERB VBD
# his PRON PRP$
# notebook NOUN NN
# and CCONJ CC
# wrote VERB VBD
# a DET DT
# short ADJ JJ
# story NOUN NN
# about ADP IN
# a DET DT
# brave ADJ JJ
# fox NOUN NN
# . PUNCT .
#
#  SPACE _SP
# While SCONJ IN
# the DET DT
# fox NOUN NN
# ran VERB VBD
# through ADP IN
# the DET DT
# forest NOUN NN
# , PUNCT ,
# it PRON PRP
# jumped VERB VBD
# over ADP RP
# fallen VERB VBN
# trees NOUN NNS
# and CCONJ CC
# chased VERB VBD
# playful ADJ JJ
# rabbits NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Suddenly ADV RB
# , PUNCT ,
# a DET DT
# loud ADJ JJ
# noise NOUN NN
# frightened VERB VBD
# the DET DT
# animals NOUN NNS
# , PUNCT ,
# but CCONJ CC
# the DET DT
# fox NOUN NN
# continued VERB VBD
# running VERB VBG
# with ADP IN
# great ADJ JJ
# determination NOUN NN

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
text = """The curious student quickly opened his notebook and wrote a short story about a brave fox.
While the fox ran through the forest, it jumped over fallen trees and chased playful rabbits.
Suddenly, a loud noise frightened the animals, but the fox continued running with great determination"""
doc = nlp(text)
nouns = []
verbs = []
for token in doc:
    if token.pos_ in ["NOUN", "PROPN"]:
        nouns.append(token.text)
    elif token.pos_ == "VERB":
        verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'fox': 3, 'student': 1, 'notebook': 1, 'story': 1, 'forest': 1, 'trees': 1, 'rabbits': 1, 'noise': 1, 'animals': 1, 'determination': 1})
# Verb Frequency: Counter({'opened': 1, 'wrote': 1, 'ran': 1, 'jumped': 1, 'fallen': 1, 'chased': 1, 'frightened': 1, 'continued': 1, 'running': 1})
